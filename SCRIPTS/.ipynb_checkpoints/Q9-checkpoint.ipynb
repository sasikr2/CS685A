# %%
import pandas as pd
import numpy as np

# %%
data8 = pd.read_excel("DDW-0000C-08.xlsx", skiprows = [0,1,2,3,5,6])

# %%
data19 = pd.read_excel("DDW-C19-0000.xlsx",skiprows = [0,1,2,4,5])

# %%
data19e = data19[data19['Urban/'] == 'Total']
data19e = data19e[["Unnamed: 2","Unnamed: 4" ,"Persons", "Males", "Females","Persons.1", "Males.1","Females.1"]]

# %%
data8.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      C2308           0           0      INDIA      Total   All ages
# 1      C2308           0           0      INDIA      Total        0-6
# 2      C2308           0           0      INDIA      Total          7
# 3      C2308           0           0      INDIA      Total          8
# 4      C2308           0           0      INDIA      Total          9
#
#       Persons      Males    Females  Persons.1  ...  Persons.10  Males.10  \
# 0  1210854977  623270258  587584719  447216165  ...     7238719   5354161
# 1   164515253   85752254   78762999  164515253  ...           0         0
# 2    24826640   12903364   11923276    6748214  ...           0         0
# 3    26968373   14061937   12906436    4131414  ...           0         0
# 4    23424638   12214985   11209653    2491904  ...           0         0
#
#    Females.10  Persons.11  Males.11  Females.11  Persons.12  Males.12  \
# 0     1884558    68288971  42120460    26168511     3031570   1647116
# 1           0           0         0           0           0         0
# 2           0           0         0           0      136465     75715
# 3           0           0         0           0       96524     52561
# 4           0           0         0           0       70452     38456
#
#    Females.12  Unnamed: 45
# 0     1384454          NaN
# 1           0          NaN
# 2       60750          NaN
# 3       43963          NaN
# 4       31996          NaN
#
# [5 rows x 46 columns]

# %%
data8i = data8[(data8['Unnamed: 5'] == 'All ages') & (data8['Unnamed: 4'] == 'Total')]

# %%
data8i.head()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2                Unnamed: 3 Unnamed: 4  \
# 0        C2308           0           0                     INDIA      Total
# 87       C2308           1           0   State - JAMMU & KASHMIR      Total
# 174      C2308           2           0  State - HIMACHAL PRADESH      Total
# 261      C2308           3           0            State - PUNJAB      Total
# 348      C2308           4           0        State - CHANDIGARH      Total
#
#     Unnamed: 5     Persons      Males    Females  Persons.1  ...  Persons.10  \
# 0     All ages  1210854977  623270258  587584719  447216165  ...     7238719
# 87    All ages    12541302    6640662    5900640    5474069  ...       50822
# 174   All ages     6864602    3481873    3382729    1824866  ...       53413
# 261   All ages    27743338   14639465   13103873    9036201  ...      234365
# 348   All ages     1055450     580663     474787     250012  ...       13801
#
#      Males.10  Females.10  Persons.11  Males.11  Females.11  Persons.12  \
# 0     5354161     1884558    68288971  42120460    26168511     3031570
# 87      33854       16968      653764    401279      252485       33609
# 174     37213       16200      446609    251164      195445        9637
# 261    147801       86564     1760846    873776      887070       42234
# 348      9660        4141      194453    104748       89705        1628
#
#      Males.12  Females.12  Unnamed: 45
# 0     1647116     1384454          NaN
# 87      19744       13865          NaN
# 174      4768        4869          NaN
# 261     22645       19589          NaN
# 348       801         827          NaN
#
# [5 rows x 46 columns]

# %%
data8i["Unnamed: 3"] = data8i["Unnamed: 3"].apply(lambda x: str(x).upper() if (str(x) == "INDIA") else str(x)[8:])
# Out:
# <ipython-input-111-8d315b3ef7e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8i["Unnamed: 3"] = data8i["Unnamed: 3"].apply(lambda x: str(x).upper() if (str(x) == "INDIA") else str(x)[8:])

# %%
data19e.head(10)
# Out:
#          Unnamed: 2                           Unnamed: 4      Persons  \
# 0             INDIA                                Total  314988770.0
# 1             INDIA                           Illiterate   42266268.0
# 2             INDIA                             Literate  272722502.0
# 3             INDIA           Literate but below primary   29345104.0
# 4             INDIA             Primary but below middle   48570544.0
# 5             INDIA    Middle but below matric/secondary   43116661.0
# 6             INDIA  Matric/Secondary but below graduate   93204075.0
# 7             INDIA                   Graduate and above   46958049.0
# 24  JAMMU & KASHMIR                                Total    6183190.0
# 25  JAMMU & KASHMIR                           Illiterate     764675.0
#
#           Males      Females   Persons.1     Males.1   Females.1
# 0   176696383.0  138292387.0  86009580.0  50536832.0  35472748.0
# 1    17851584.0   24414684.0   3879858.0   1890285.0   1989573.0
# 2   158844799.0  113877703.0  82129722.0  48646547.0  33483175.0
# 3    16126959.0   13218145.0   3733616.0   2108024.0   1625592.0
# 4    26588496.0   21982048.0   8636296.0   4782211.0   3854085.0
# 5    25214857.0   17901804.0  10743350.0   6266289.0   4477061.0
# 6    56022449.0   37181626.0  33899219.0  20411147.0  13488072.0
# 7    28285620.0   18672429.0  22146543.0  13316422.0   8830121.0
# 24    3634819.0    2548371.0   2096220.0   1258756.0    837464.0
# 25     343219.0     421456.0    132783.0     62798.0     69985.0

# %%
districts = data19e['Unnamed: 2'].unique()

# %%
# Illiterate   ==> 1
# Literate   ==> 2
# Literate but below primary   ==> 4
# Primary but below middle    ==> 5
# Middle but below matric/secondary   ==> 6
# Matric/Secondary but below graduate   ==> 7
# Graduate and above        ==> 11

# %%
def make_dist(datai, district, data19i, idx):
    # datai = data13[0]\
    #print(datai["Unnamed: 3"].unique())
    datai = datai[datai["Unnamed: 3"] == district]
    #print(datai.shape, data19.shape)
    mx = 0
    st = 0
    for i in range(0,7):
        tot = datai.iloc[0,i+1]
        succ  = data19i.iloc[i+1,idx]   #data19
        #print(succ)
        #grp.append(data19.iloc[i+1,1])
        if (succ / tot) > mx:
            mx = (succ / tot)
            st = i
#         tott.append(tot)
#         succs.append(succ)
        if(mx > 1.0):
            #print(datai)
            #print(data19i)
            pass
    return mx,data19i.iloc[st+1,1]

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-males'] = []
final_dict['ratio-males'] = []
category = 'Males'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist(datai_new,district, data19ee, 6)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-males'].append(b)
    final_dict['ratio-males'].append(a)

# %%
final_dict_dfm3 = pd.DataFrame(final_dict)
final_dict_dfm3.head(50)
# Out:
#                        states                 literacy-group-males  \
# 0                       INDIA  Matric/Secondary but below graduate
# 1             JAMMU & KASHMIR                   Graduate and above
# 2            HIMACHAL PRADESH  Matric/Secondary but below graduate
# 3                      PUNJAB  Matric/Secondary but below graduate
# 4                  CHANDIGARH  Matric/Secondary but below graduate
# 5                 UTTARAKHAND                   Graduate and above
# 6                     HARYANA                   Graduate and above
# 7                NCT OF DELHI                   Graduate and above
# 8                   RAJASTHAN  Matric/Secondary but below graduate
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR                   Graduate and above
# 11                     SIKKIM  Matric/Secondary but below graduate
# 12          ARUNACHAL PRADESH  Matric/Secondary but below graduate
# 13                   NAGALAND  Matric/Secondary but below graduate
# 14                    MANIPUR  Matric/Secondary but below graduate
# 15                    MIZORAM                   Graduate and above
# 16                    TRIPURA  Matric/Secondary but below graduate
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM  Matric/Secondary but below graduate
# 19                WEST BENGAL                   Graduate and above
# 20                  JHARKHAND  Matric/Secondary but below graduate
# 21                     ODISHA  Matric/Secondary but below graduate
# 22               CHHATTISGARH                   Graduate and above
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT                   Graduate and above
# 25                DAMAN & DIU                   Graduate and above
# 26       DADRA & NAGAR HAVELI  Matric/Secondary but below graduate
# 27                MAHARASHTRA                   Graduate and above
# 28             ANDHRA PRADESH                   Graduate and above
# 29                  KARNATAKA  Matric/Secondary but below graduate
# 30                        GOA  Matric/Secondary but below graduate
# 31                LAKSHADWEEP  Matric/Secondary but below graduate
# 32                     KERALA  Matric/Secondary but below graduate
# 33                 TAMIL NADU                   Graduate and above
# 34                 PUDUCHERRY                   Graduate and above
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-males
# 0      0.320075
# 1      0.669791
# 2      0.158217
# 3      0.944362
# 4      0.782279
# 5      0.071985
# 6      0.169245
# 7      0.232764
# 8      0.079364
# 9      0.064937
# 10     0.085916
# 11     0.968674
# 12     0.982101
# 13     0.934625
# 14     0.706602
# 15     0.276086
# 16     0.384725
# 17     0.610509
# 18     1.075416
# 19     0.244607
# 20     0.194870
# 21     0.723041
# 22     0.098255
# 23     0.108597
# 24     0.700751
# 25     0.532344
# 26     0.535081
# 27     0.642005
# 28     0.375135
# 29     0.618464
# 30     1.615242
# 31     0.964330
# 32     0.439666
# 33     0.153287
# 34     0.217898
# 35     0.676966

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-females'] = []
final_dict['ratio-females'] = []
category = 'Females'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist(datai_new,district, data19ee, 7)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-females'].append(b)
    final_dict['ratio-females'].append(a)

# %%
final_dict_dff3 = pd.DataFrame(final_dict)
final_dict_dff3.head(50)
# Out:
#                        states               literacy-group-females  \
# 0                       INDIA                   Graduate and above
# 1             JAMMU & KASHMIR                   Graduate and above
# 2            HIMACHAL PRADESH  Matric/Secondary but below graduate
# 3                      PUNJAB  Matric/Secondary but below graduate
# 4                  CHANDIGARH  Matric/Secondary but below graduate
# 5                 UTTARAKHAND                   Graduate and above
# 6                     HARYANA                   Graduate and above
# 7                NCT OF DELHI                   Graduate and above
# 8                   RAJASTHAN  Matric/Secondary but below graduate
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR                   Graduate and above
# 11                     SIKKIM  Matric/Secondary but below graduate
# 12          ARUNACHAL PRADESH  Matric/Secondary but below graduate
# 13                   NAGALAND  Matric/Secondary but below graduate
# 14                    MANIPUR  Matric/Secondary but below graduate
# 15                    MIZORAM                   Graduate and above
# 16                    TRIPURA                   Graduate and above
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM  Matric/Secondary but below graduate
# 19                WEST BENGAL                   Graduate and above
# 20                  JHARKHAND                   Graduate and above
# 21                     ODISHA                   Graduate and above
# 22               CHHATTISGARH                   Graduate and above
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT                   Graduate and above
# 25                DAMAN & DIU                   Graduate and above
# 26       DADRA & NAGAR HAVELI  Matric/Secondary but below graduate
# 27                MAHARASHTRA                   Graduate and above
# 28             ANDHRA PRADESH                   Graduate and above
# 29                  KARNATAKA  Matric/Secondary but below graduate
# 30                        GOA  Matric/Secondary but below graduate
# 31                LAKSHADWEEP  Matric/Secondary but below graduate
# 32                     KERALA                   Graduate and above
# 33                 TAMIL NADU                   Graduate and above
# 34                 PUDUCHERRY                   Graduate and above
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-females
# 0        0.337433
# 1        0.680314
# 2        0.157495
# 3        0.994618
# 4        0.923263
# 5        0.073002
# 6        0.196280
# 7        0.247149
# 8        0.088719
# 9        0.069244
# 10       0.084491
# 11       1.157066
# 12       1.042850
# 13       0.943479
# 14       0.661600
# 15       0.209615
# 16       0.313940
# 17       0.493885
# 18       0.851553
# 19       0.244835
# 20       0.217443
# 21       0.655997
# 22       0.129118
# 23       0.117693
# 24       0.670003
# 25       0.579392
# 26       0.638598
# 27       0.656895
# 28       0.362510
# 29       0.515514
# 30       1.565563
# 31       0.688862
# 32       0.353019
# 33       0.145446
# 34       0.204870
# 35       0.686578

# %%
final_data_tri = pd.merge(final_dict_dfm3, final_dict_dff3, how = 'outer', right_on = 'states', left_on = 'states')

# %%
final_data_tri.to_csv('literacy-gender-3.csv')
print("literacy-gender-3.csv is created")
# Out:
# literacy-gender-3.csv is created

# %%
def make_dist_bilingual(datai, district, data19i, idx):
    # datai = data13[0]\
    #print(datai["Unnamed: 3"].unique())
    datai = datai[datai["Unnamed: 3"] == district]
    #print(datai.shape, data19.shape)
    mx = 0
    st = 0
    for i in range(0,7):
        tot = datai.iloc[0,i+1]
        succ  = data19i.iloc[i+1,idx] - data19i.iloc[i+1, idx+2]   #data19
        #print(succ)
        #grp.append(data19.iloc[i+1,1])
        if (succ / tot) > mx:
            mx = (succ / tot)
            st = i
#         tott.append(tot)
#         succs.append(succ)
        if(mx > 1.0):
            #print(datai)
            #print(data19i)
            pass
    return mx,data19i.iloc[st+1,1]

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-males'] = []
final_dict['ratio-males'] = []
category = 'Males'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist_bilingual(datai_new,district, data19ee, 4)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-males'].append(b)
    final_dict['ratio-males'].append(a)

# %%
final_dict_dfm2 = pd.DataFrame(final_dict)
final_dict_dfm2.head(50)
# Out:
#                        states                 literacy-group-males  \
# 0                       INDIA  Matric/Secondary but below graduate
# 1             JAMMU & KASHMIR             Primary but below middle
# 2            HIMACHAL PRADESH                   Graduate and above
# 3                      PUNJAB             Primary but below middle
# 4                  CHANDIGARH             Primary but below middle
# 5                 UTTARAKHAND                   Graduate and above
# 6                     HARYANA                   Graduate and above
# 7                NCT OF DELHI  Matric/Secondary but below graduate
# 8                   RAJASTHAN                   Graduate and above
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR           Literate but below primary
# 11                     SIKKIM             Primary but below middle
# 12          ARUNACHAL PRADESH           Literate but below primary
# 13                   NAGALAND             Primary but below middle
# 14                    MANIPUR             Primary but below middle
# 15                    MIZORAM  Matric/Secondary but below graduate
# 16                    TRIPURA  Matric/Secondary but below graduate
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM                           Illiterate
# 19                WEST BENGAL  Matric/Secondary but below graduate
# 20                  JHARKHAND           Literate but below primary
# 21                     ODISHA                           Illiterate
# 22               CHHATTISGARH  Matric/Secondary but below graduate
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT             Primary but below middle
# 25                DAMAN & DIU             Primary but below middle
# 26       DADRA & NAGAR HAVELI                           Illiterate
# 27                MAHARASHTRA             Primary but below middle
# 28             ANDHRA PRADESH  Matric/Secondary but below graduate
# 29                  KARNATAKA  Matric/Secondary but below graduate
# 30                        GOA           Literate but below primary
# 31                LAKSHADWEEP    Middle but below matric/secondary
# 32                     KERALA  Matric/Secondary but below graduate
# 33                 TAMIL NADU  Matric/Secondary but below graduate
# 34                 PUDUCHERRY  Matric/Secondary but below graduate
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-males
# 0     26.298452
# 1     40.760404
# 2     15.306732
# 3     23.558196
# 4     20.756331
# 5     26.081302
# 6     30.055613
# 7     53.740556
# 8     13.399037
# 9     21.405683
# 10    16.694626
# 11    32.765224
# 12    38.172951
# 13    41.555754
# 14    33.349102
# 15    71.006813
# 16    39.490278
# 17    50.308169
# 18    31.744428
# 19    26.712880
# 20    26.631189
# 21    19.382339
# 22    17.064483
# 23    20.393569
# 24    36.806865
# 25    26.366708
# 26    39.844650
# 27    41.243135
# 28    24.532460
# 29    42.275780
# 30    47.404251
# 31     7.537688
# 32    50.040293
# 33    59.870461
# 34    67.933538
# 35    50.520094

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-females'] = []
final_dict['ratio-females'] = []
category = 'Females'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist(datai_new,district, data19ee, 5)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-females'].append(b)
    final_dict['ratio-females'].append(a)

# %%
final_dict_dff2 = pd.DataFrame(final_dict)
final_dict_dff2.head(50)
# Out:
#                        states               literacy-group-females  \
# 0                       INDIA                   Graduate and above
# 1             JAMMU & KASHMIR                   Graduate and above
# 2            HIMACHAL PRADESH  Matric/Secondary but below graduate
# 3                      PUNJAB  Matric/Secondary but below graduate
# 4                  CHANDIGARH  Matric/Secondary but below graduate
# 5                 UTTARAKHAND  Matric/Secondary but below graduate
# 6                     HARYANA  Matric/Secondary but below graduate
# 7                NCT OF DELHI                   Graduate and above
# 8                   RAJASTHAN  Matric/Secondary but below graduate
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR                   Graduate and above
# 11                     SIKKIM  Matric/Secondary but below graduate
# 12          ARUNACHAL PRADESH  Matric/Secondary but below graduate
# 13                   NAGALAND  Matric/Secondary but below graduate
# 14                    MANIPUR                   Graduate and above
# 15                    MIZORAM                   Graduate and above
# 16                    TRIPURA                   Graduate and above
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM  Matric/Secondary but below graduate
# 19                WEST BENGAL                   Graduate and above
# 20                  JHARKHAND                   Graduate and above
# 21                     ODISHA                   Graduate and above
# 22               CHHATTISGARH                   Graduate and above
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT                   Graduate and above
# 25                DAMAN & DIU                   Graduate and above
# 26       DADRA & NAGAR HAVELI  Matric/Secondary but below graduate
# 27                MAHARASHTRA                   Graduate and above
# 28             ANDHRA PRADESH                   Graduate and above
# 29                  KARNATAKA                   Graduate and above
# 30                        GOA  Matric/Secondary but below graduate
# 31                LAKSHADWEEP  Matric/Secondary but below graduate
# 32                     KERALA  Matric/Secondary but below graduate
# 33                 TAMIL NADU                   Graduate and above
# 34                 PUDUCHERRY                   Graduate and above
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-females
# 0        0.846305
# 1        1.744824
# 2        0.385992
# 3        2.356720
# 4        2.194039
# 5        0.177200
# 6        0.440734
# 7        0.539749
# 8        0.263214
# 9        0.186187
# 10       0.356178
# 11       2.528710
# 12       2.525846
# 13       2.178257
# 14       1.611412
# 15       0.615308
# 16       0.947307
# 17       1.217254
# 18       2.194725
# 19       0.679251
# 20       0.631897
# 21       1.952759
# 22       0.309115
# 23       0.307803
# 24       1.703966
# 25       1.604067
# 26       1.988073
# 27       1.612608
# 28       1.063225
# 29       1.273016
# 30       3.554442
# 31       1.931827
# 32       0.772008
# 33       0.349926
# 34       0.481766
# 35       1.612356

# %%
final_data_bi = pd.merge(final_dict_dfm2, final_dict_dff2, how = 'outer', right_on = 'states', left_on = 'states')

# %%
final_data_bi.to_csv('literacy-gender-2.csv')
print("literacy-gender-2.csv is created")
# Out:
# literacy-gender-2.csv is created

# %%
def make_dist_single(datai, district, data19i, idx):
    # datai = data13[0]\
    #print(datai["Unnamed: 3"].unique())
    datai = datai[datai["Unnamed: 3"] == district]
    #print(datai.shape, data19.shape)
    mx = 0
    st = 0
    for i in range(0,7):
        tot = datai.iloc[0,i+1]
        succ  = data19i.iloc[i+1,idx] + data19i.iloc[i+1,idx+2]   #data19
        #print(succ)
        #grp.append(data19.iloc[i+1,1])
        if (1 - (succ / tot)) > mx:
            mx = (1 - (succ / tot))
            st = i
#         tott.append(tot)
#         succs.append(succ)
        if(mx > 1.0):
            #print(datai)
            #print(data19i)
            pass
    return mx,data19i.iloc[st+1,1]

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-males'] = []
final_dict['ratio-males'] = []
category = 'Males'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist_bilingual(datai_new,district, data19ee, 4)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-males'].append(b)
    final_dict['ratio-males'].append(a)

# %%
final_dict_dfm1 = pd.DataFrame(final_dict)
final_dict_dfm1.head(50)
# Out:
#                        states                 literacy-group-males  \
# 0                       INDIA  Matric/Secondary but below graduate
# 1             JAMMU & KASHMIR             Primary but below middle
# 2            HIMACHAL PRADESH                   Graduate and above
# 3                      PUNJAB             Primary but below middle
# 4                  CHANDIGARH             Primary but below middle
# 5                 UTTARAKHAND                   Graduate and above
# 6                     HARYANA                   Graduate and above
# 7                NCT OF DELHI  Matric/Secondary but below graduate
# 8                   RAJASTHAN                   Graduate and above
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR           Literate but below primary
# 11                     SIKKIM             Primary but below middle
# 12          ARUNACHAL PRADESH           Literate but below primary
# 13                   NAGALAND             Primary but below middle
# 14                    MANIPUR             Primary but below middle
# 15                    MIZORAM  Matric/Secondary but below graduate
# 16                    TRIPURA  Matric/Secondary but below graduate
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM                           Illiterate
# 19                WEST BENGAL  Matric/Secondary but below graduate
# 20                  JHARKHAND           Literate but below primary
# 21                     ODISHA                           Illiterate
# 22               CHHATTISGARH  Matric/Secondary but below graduate
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT             Primary but below middle
# 25                DAMAN & DIU             Primary but below middle
# 26       DADRA & NAGAR HAVELI                           Illiterate
# 27                MAHARASHTRA             Primary but below middle
# 28             ANDHRA PRADESH  Matric/Secondary but below graduate
# 29                  KARNATAKA  Matric/Secondary but below graduate
# 30                        GOA           Literate but below primary
# 31                LAKSHADWEEP    Middle but below matric/secondary
# 32                     KERALA  Matric/Secondary but below graduate
# 33                 TAMIL NADU  Matric/Secondary but below graduate
# 34                 PUDUCHERRY  Matric/Secondary but below graduate
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-males
# 0     26.298452
# 1     40.760404
# 2     15.306732
# 3     23.558196
# 4     20.756331
# 5     26.081302
# 6     30.055613
# 7     53.740556
# 8     13.399037
# 9     21.405683
# 10    16.694626
# 11    32.765224
# 12    38.172951
# 13    41.555754
# 14    33.349102
# 15    71.006813
# 16    39.490278
# 17    50.308169
# 18    31.744428
# 19    26.712880
# 20    26.631189
# 21    19.382339
# 22    17.064483
# 23    20.393569
# 24    36.806865
# 25    26.366708
# 26    39.844650
# 27    41.243135
# 28    24.532460
# 29    42.275780
# 30    47.404251
# 31     7.537688
# 32    50.040293
# 33    59.870461
# 34    67.933538
# 35    50.520094

# %%
final_dict = {}
final_dict['states'] =[]
final_dict['literacy-group-females'] = []
final_dict['ratio-females'] = []
category = 'Females'
datai_new = data8i[['Unnamed: 3',category+'.1',category+'.2',category+'.4',category+'.5',category+'.6',category+'.7',category+'.11',]]
for district in districts:
    #if district == "INDIA":
    #    continue
#     print(district)
    data19ee = data19e[data19e['Unnamed: 2'] == district]
    a, b = make_dist(datai_new,district, data19ee, 5)
#     print(a, b,district)
    final_dict['states'].append(district)
    final_dict['literacy-group-females'].append(b)
    final_dict['ratio-females'].append(a)

# %%
final_dict_dff1 = pd.DataFrame(final_dict)
final_dict_dff1.head(50)
# Out:
#                        states               literacy-group-females  \
# 0                       INDIA                   Graduate and above
# 1             JAMMU & KASHMIR                   Graduate and above
# 2            HIMACHAL PRADESH  Matric/Secondary but below graduate
# 3                      PUNJAB  Matric/Secondary but below graduate
# 4                  CHANDIGARH  Matric/Secondary but below graduate
# 5                 UTTARAKHAND  Matric/Secondary but below graduate
# 6                     HARYANA  Matric/Secondary but below graduate
# 7                NCT OF DELHI                   Graduate and above
# 8                   RAJASTHAN  Matric/Secondary but below graduate
# 9               UTTAR PRADESH                   Graduate and above
# 10                      BIHAR                   Graduate and above
# 11                     SIKKIM  Matric/Secondary but below graduate
# 12          ARUNACHAL PRADESH  Matric/Secondary but below graduate
# 13                   NAGALAND  Matric/Secondary but below graduate
# 14                    MANIPUR                   Graduate and above
# 15                    MIZORAM                   Graduate and above
# 16                    TRIPURA                   Graduate and above
# 17                  MEGHALAYA  Matric/Secondary but below graduate
# 18                      ASSAM  Matric/Secondary but below graduate
# 19                WEST BENGAL                   Graduate and above
# 20                  JHARKHAND                   Graduate and above
# 21                     ODISHA                   Graduate and above
# 22               CHHATTISGARH                   Graduate and above
# 23             MADHYA PRADESH                   Graduate and above
# 24                    GUJARAT                   Graduate and above
# 25                DAMAN & DIU                   Graduate and above
# 26       DADRA & NAGAR HAVELI  Matric/Secondary but below graduate
# 27                MAHARASHTRA                   Graduate and above
# 28             ANDHRA PRADESH                   Graduate and above
# 29                  KARNATAKA                   Graduate and above
# 30                        GOA  Matric/Secondary but below graduate
# 31                LAKSHADWEEP  Matric/Secondary but below graduate
# 32                     KERALA  Matric/Secondary but below graduate
# 33                 TAMIL NADU                   Graduate and above
# 34                 PUDUCHERRY                   Graduate and above
# 35  ANDAMAN & NICOBAR ISLANDS  Matric/Secondary but below graduate
#
#     ratio-females
# 0        0.846305
# 1        1.744824
# 2        0.385992
# 3        2.356720
# 4        2.194039
# 5        0.177200
# 6        0.440734
# 7        0.539749
# 8        0.263214
# 9        0.186187
# 10       0.356178
# 11       2.528710
# 12       2.525846
# 13       2.178257
# 14       1.611412
# 15       0.615308
# 16       0.947307
# 17       1.217254
# 18       2.194725
# 19       0.679251
# 20       0.631897
# 21       1.952759
# 22       0.309115
# 23       0.307803
# 24       1.703966
# 25       1.604067
# 26       1.988073
# 27       1.612608
# 28       1.063225
# 29       1.273016
# 30       3.554442
# 31       1.931827
# 32       0.772008
# 33       0.349926
# 34       0.481766
# 35       1.612356

# %%
final_data_si = pd.merge(final_dict_dfm1, final_dict_dff1, how = 'outer', right_on = 'states', left_on = 'states')

# %%
final_data_si.to_csv('literacy-gender-1.csv')
print("literacy-gender-1.csv is created")
# Out:
# literacy-gender-1.csv is created
